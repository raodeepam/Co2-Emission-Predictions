# %%
import pandas as pd

# %%
df = pd.read_csv('/content/owid-co2-data.csv')

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3769828.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3787706.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3806634.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3825655.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
df.shape
# Out:
# (46523, 74)

# %%
df_1 = df[ ['country', 'year','iso_code','population','co2'] ]

# %%
df_1.shape
# Out:
# (46523, 5)

# %%
df_1
# Out:
#            country  year iso_code  population     co2
# 0      Afghanistan  1850      AFG   3752993.0     NaN
# 1      Afghanistan  1851      AFG   3769828.0     NaN
# 2      Afghanistan  1852      AFG   3787706.0     NaN
# 3      Afghanistan  1853      AFG   3806634.0     NaN
# 4      Afghanistan  1854      AFG   3825655.0     NaN
# ...            ...   ...      ...         ...     ...
# 46518     Zimbabwe  2017      ZWE  14751101.0   9.596
# 46519     Zimbabwe  2018      ZWE  15052191.0  11.795
# 46520     Zimbabwe  2019      ZWE  15354606.0  11.115
# 46521     Zimbabwe  2020      ZWE  15669663.0  10.608
# 46522     Zimbabwe  2021      ZWE  15993525.0  11.296
#
# [46523 rows x 5 columns]

# %%
df_clean = df_1.dropna()

# %%
df_clean.shape
# Out:
# (23047, 5)

# %%
df_clean
# Out:
#            country  year iso_code  population     co2
# 99     Afghanistan  1949      AFG   7624058.0   0.015
# 100    Afghanistan  1950      AFG   7480464.0   0.084
# 101    Afghanistan  1951      AFG   7571542.0   0.092
# 102    Afghanistan  1952      AFG   7667534.0   0.092
# 103    Afghanistan  1953      AFG   7764549.0   0.106
# ...            ...   ...      ...         ...     ...
# 46518     Zimbabwe  2017      ZWE  14751101.0   9.596
# 46519     Zimbabwe  2018      ZWE  15052191.0  11.795
# 46520     Zimbabwe  2019      ZWE  15354606.0  11.115
# 46521     Zimbabwe  2020      ZWE  15669663.0  10.608
# 46522     Zimbabwe  2021      ZWE  15993525.0  11.296
#
# [23047 rows x 5 columns]

# %%
df_afg = df_clean.loc[ (df['country'] == 'Afghanistan') , :]

# %%
df_ind = df_clean.loc[ (df['country'] == 'India') , :]
df_us = df_clean.loc[ (df['country'] == 'United States') , :]
df_uk = df_clean.loc[ (df['country'] == 'United Kingdom') , :]
df_uae = df_clean.loc[ (df['country'] == 'United Arab Emirates') , :]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Afganistan's co2 emmission over the years

# %%
df_afg.plot.scatter(x='year', y='co2' )
# Out:
# <AxesSubplot:xlabel='year', ylabel='co2'>

# %% [markdown]
# # The following line graph shows the carbon emmission of 5 countries over a period of time
#
# - we can see that USA has the most amount of carbon emmission and afganistan has the least
# - UK has a dip in co2 emmission for the past few years
# - Carbon emmission in India has grown rapidly around year 2000

# %%
plt.plot(df_afg['year'], df_afg['co2'], label='afg')
plt.plot(df_ind['year'], df_ind['co2'],label='ind')
plt.plot(df_us['year'], df_us['co2'],label='USA')
plt.plot(df_uk['year'], df_uk['co2'],label='UK')
plt.plot(df_uae['year'], df_uae['co2'],label='UAE')
plt.xlabel('Year')
plt.ylabel('co2 emmission')
plt.legend()

# %%
df_us
# Out:
#              country  year iso_code   population       co2
# 44001  United States  1800      USA    6000000.0     0.253
# 44002  United States  1801      USA    6113782.0     0.267
# 44003  United States  1802      USA    6229723.0     0.289
# 44004  United States  1803      USA    6347862.0     0.297
# 44005  United States  1804      USA    6468241.0     0.333
# ...              ...   ...      ...          ...       ...
# 44218  United States  2017      USA  329791232.0  5210.958
# 44219  United States  2018      USA  332140032.0  5376.657
# 44220  United States  2019      USA  334319680.0  5259.144
# 44221  United States  2020      USA  335942016.0  4715.691
# 44222  United States  2021      USA  336997632.0  5007.336
#
# [222 rows x 5 columns]

# %%
plt.plot(df_us['year'], df_us['co2'],label='USA')

# %%
df_us_last = df_us.loc[ (df_us['year'] > 2000), :]

# %%
df_us_last
# Out:
#              country  year iso_code   population       co2
# 44202  United States  2001      USA  285470496.0  5911.988
# 44203  United States  2002      USA  288350240.0  5952.699
# 44204  United States  2003      USA  291109824.0  6015.804
# 44205  United States  2004      USA  293947872.0  6117.963
# 44206  United States  2005      USA  296842656.0  6137.604
# 44207  United States  2006      USA  299753088.0  6057.163
# 44208  United States  2007      USA  302743392.0  6135.287
# 44209  United States  2008      USA  305694912.0  5918.869
# 44210  United States  2009      USA  308512032.0  5482.978
# 44211  United States  2010      USA  311182848.0  5681.392
# 44212  United States  2011      USA  313876608.0  5546.629
# 44213  United States  2012      USA  316651328.0  5345.454
# 44214  United States  2013      USA  319375168.0  5480.926
# 44215  United States  2014      USA  322033952.0  5528.871
# 44216  United States  2015      USA  324607776.0  5376.578
# ...

# %%
df_us_s = df_us_last[ ['population','co2'] ]

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()
std.fit(df_us_s)
# Out:
# StandardScaler()

# %%
df_us_std = std.transform(df_us_s)

# %%
df_us_std
# Out:
# array([[-1.71097344,  0.80032315],
#        [-1.53308904,  0.90336849],
#        [-1.36262704,  1.06309623],
#        [-1.18731824,  1.32167522],
#        [-1.00850481,  1.37138939],
#        [-0.82872479,  1.16778176],
#        [-0.644011  ,  1.36552473],
#        [-0.46169293,  0.81773994],
#        [-0.28767688, -0.28556229],
#        [-0.12269815,  0.21665181],
#        [ 0.04369785, -0.12445254],
#        [ 0.21509481, -0.63365513],
#        [ 0.38334888, -0.29075619],
#        [ 0.54758438, -0.16940057],
#        [ 0.70657182, -0.55487585],
#        [ 0.8673264 , -0.87081558],
#        [ 1.02675859, -0.97408367],
#        [ 1.1718461 , -0.55467589],
#        [ 1.30648493, -0.85211804],
#        [ 1.4066981 , -2.22767501],
#        [ 1.47190445, -1.48947996]])

# %%
cols = ['population','co2']

# %%
df_cat2 = pd.DataFrame(df_us_std,columns=cols)
df_cat2
# Out:
#     population       co2
# 0    -1.710973  0.800323
# 1    -1.533089  0.903368
# 2    -1.362627  1.063096
# 3    -1.187318  1.321675
# 4    -1.008505  1.371389
# 5    -0.828725  1.167782
# 6    -0.644011  1.365525
# 7    -0.461693  0.817740
# 8    -0.287677 -0.285562
# 9    -0.122698  0.216652
# 10    0.043698 -0.124453
# 11    0.215095 -0.633655
# 12    0.383349 -0.290756
# 13    0.547584 -0.169401
# 14    0.706572 -0.554876
# 15    0.867326 -0.870816
# 16    1.026759 -0.974084
# 17    1.171846 -0.554676
# 18    1.306485 -0.852118
# 19    1.406698 -2.227675
# 20    1.471904 -1.489480

# %%
df_cat1 = df_us_last[ ['country', 'year','iso_code'] ]
# df_cat1.reset_index()
df_cat1 = df_cat1.assign(Index=range(len(df_cat1))).set_index('Index')
df_cat1
# Out:
#              country  year iso_code
# Index
# 0      United States  2001      USA
# 1      United States  2002      USA
# 2      United States  2003      USA
# 3      United States  2004      USA
# 4      United States  2005      USA
# 5      United States  2006      USA
# 6      United States  2007      USA
# 7      United States  2008      USA
# 8      United States  2009      USA
# 9      United States  2010      USA
# 10     United States  2011      USA
# 11     United States  2012      USA
# 12     United States  2013      USA
# 13     United States  2014      USA
# 14     United States  2015      USA
# 15     United States  2016      USA
# 16     United States  2017      USA
# 17     United States  2018      USA
# 18     United States  2019      USA
# 19     United States  2020      USA
# 20     United States  2021      USA

# %%
df_us_std = pd.concat([df_cat1,df_cat2],axis=1)

# %%
df_us_std
# Out:
#           country  year iso_code  population       co2
# 0   United States  2001      USA   -1.710973  0.800323
# 1   United States  2002      USA   -1.533089  0.903368
# 2   United States  2003      USA   -1.362627  1.063096
# 3   United States  2004      USA   -1.187318  1.321675
# 4   United States  2005      USA   -1.008505  1.371389
# 5   United States  2006      USA   -0.828725  1.167782
# 6   United States  2007      USA   -0.644011  1.365525
# 7   United States  2008      USA   -0.461693  0.817740
# 8   United States  2009      USA   -0.287677 -0.285562
# 9   United States  2010      USA   -0.122698  0.216652
# 10  United States  2011      USA    0.043698 -0.124453
# 11  United States  2012      USA    0.215095 -0.633655
# 12  United States  2013      USA    0.383349 -0.290756
# 13  United States  2014      USA    0.547584 -0.169401
# 14  United States  2015      USA    0.706572 -0.554876
# 15  United States  2016      USA    0.867326 -0.870816
# ...

# %%
plt.plot(df_us_std['year'], df_us_std['co2'],label='co2 emmision')
plt.plot(df_us_std['year'], df_us_std['population'],label='population')
plt.legend()

# %% [markdown]
# # Above graph tells us that population was not the reason behind decrease in co2 emmission

# %%
df_for_gdp = df[ ['country', 'year','gdp','co2'] ]
df_gdp_clean = df_for_gdp.dropna()

# %%
df_us_gdp = df_gdp_clean.loc[ (df['country'] == 'United States') , :]
df_us_gdp
# Out:
#              country  year           gdp       co2
# 44021  United States  1820  2.668967e+10     0.791
# 44022  United States  1821  2.796371e+10     0.828
# 44023  United States  1822  2.965757e+10     0.865
# 44024  United States  1823  3.022677e+10     0.901
# 44025  United States  1824  3.198195e+10     1.015
# ...              ...   ...           ...       ...
# 44215  United States  2014  1.648270e+13  5528.871
# 44216  United States  2015  1.690260e+13  5376.578
# 44217  United States  2016  1.716260e+13  5251.757
# 44218  United States  2017  1.759630e+13  5210.958
# 44219  United States  2018  1.814060e+13  5376.657
#
# [199 rows x 4 columns]

# %%
df_us_gdp_last = df_us_gdp.loc[ (df_us['year'] > 1950), :]
df_us_gdp_last
# Out:
#              country  year           gdp       co2
# 44152  United States  1951  2.497410e+12  2618.711
# 44153  United States  1952  2.590800e+12  2551.219
# 44154  United States  1953  2.709830e+12  2612.971
# 44155  United States  1954  2.691890e+12  2489.462
# 44156  United States  1955  2.882220e+12  2728.512
# ...              ...   ...           ...       ...
# 44215  United States  2014  1.648270e+13  5528.871
# 44216  United States  2015  1.690260e+13  5376.578
# 44217  United States  2016  1.716260e+13  5251.757
# 44218  United States  2017  1.759630e+13  5210.958
# 44219  United States  2018  1.814060e+13  5376.657
#
# [68 rows x 4 columns]

# %%
df_us_g_s = df_us_gdp_last[ ['gdp','co2'] ]
df_us_g_s
# Out:
#                 gdp       co2
# 44152  2.497410e+12  2618.711
# 44153  2.590800e+12  2551.219
# 44154  2.709830e+12  2612.971
# 44155  2.691890e+12  2489.462
# 44156  2.882220e+12  2728.512
# ...             ...       ...
# 44215  1.648270e+13  5528.871
# 44216  1.690260e+13  5376.578
# 44217  1.716260e+13  5251.757
# 44218  1.759630e+13  5210.958
# 44219  1.814060e+13  5376.657
#
# [68 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()
std.fit(df_us_g_s)
# Out:
# StandardScaler()

# %%
df_us_g_std = std.transform(df_us_g_s)

# %%
df_us_g_std
# Out:
# array([[-1.31376185e+00, -1.81675411e+00],
#        [-1.29427488e+00, -1.87767504e+00],
#        [-1.26943780e+00, -1.82193526e+00],
#        [-1.27318120e+00, -1.93341934e+00],
#        [-1.23346650e+00, -1.71764342e+00],
#        [-1.22174176e+00, -1.59896169e+00],
#        [-1.21023612e+00, -1.62082633e+00],
#        [-1.21649599e+00, -1.70085794e+00],
#        [-1.17067166e+00, -1.62430058e+00],
#        [-1.15414142e+00, -1.56527520e+00],
#        [-1.13824135e+00, -1.57470056e+00],
#        [-1.09626475e+00, -1.47809198e+00],
#        [-1.06431438e+00, -1.35841464e+00],
#        [-1.01966272e+00, -1.23400838e+00],
#        [-9.67647375e-01, -1.11194086e+00],
#        [-9.10857833e-01, -9.56800640e-01],
#        [-8.87763086e-01, -8.35810870e-01],
#        [-8.42702454e-01, -7.13541158e-01],
#        [-8.11645152e-01, -5.38225141e-01],
#        [-8.09794317e-01, -2.63334471e-01],
#        [-7.77860633e-01, -2.40065333e-01],
#        [-7.21809756e-01, -5.27225499e-02],
# ...

# %%
colsg = ['gdp','co2']

# %%
df_cat2g = pd.DataFrame(df_us_g_std,columns=colsg) 
df_cat2g
# Out:
#          gdp       co2
# 0  -1.313762 -1.816754
# 1  -1.294275 -1.877675
# 2  -1.269438 -1.821935
# 3  -1.273181 -1.933419
# 4  -1.233466 -1.717643
# ..       ...       ...
# 63  1.604441  0.810071
# 64  1.692059  0.672605
# 65  1.746311  0.559937
# 66  1.836808  0.523110
# 67  1.950383  0.672676
#
# [68 rows x 2 columns]

# %%
df_cat1g = df_us_gdp_last[ ['country', 'year'] ]
# df_cat1.reset_index()
df_cat1g = df_cat1g.assign(Index=range(len(df_cat1g))).set_index('Index')
df_cat1g
# Out:
#              country  year
# Index
# 0      United States  1951
# 1      United States  1952
# 2      United States  1953
# 3      United States  1954
# 4      United States  1955
# ...              ...   ...
# 63     United States  2014
# 64     United States  2015
# 65     United States  2016
# 66     United States  2017
# 67     United States  2018
#
# [68 rows x 2 columns]

# %%
df_us_std_gdp = pd.concat([df_cat1g,df_cat2g],axis=1)

# %%
df_us_std_gdp
# Out:
#           country  year       gdp       co2
# 0   United States  1951 -1.313762 -1.816754
# 1   United States  1952 -1.294275 -1.877675
# 2   United States  1953 -1.269438 -1.821935
# 3   United States  1954 -1.273181 -1.933419
# 4   United States  1955 -1.233466 -1.717643
# ..            ...   ...       ...       ...
# 63  United States  2014  1.604441  0.810071
# 64  United States  2015  1.692059  0.672605
# 65  United States  2016  1.746311  0.559937
# 66  United States  2017  1.836808  0.523110
# 67  United States  2018  1.950383  0.672676
#
# [68 rows x 4 columns]

# %%
plt.plot(df_us_std_gdp['year'], df_us_std_gdp['co2'],label='co2 emmision')
plt.plot(df_us_std_gdp['year'], df_us_std_gdp['gdp'],label='gdp')
plt.legend()

# %% [markdown]
# # Time series forecasting

# %%
import pandas as pd

# %%
df_ts = pd.read_csv("/content/owid-co2-data.csv", 
                 parse_dates=['year'])

# %%
df_ts
# Out:
#            country       year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan 1850-01-01      AFG   3752993.0           NaN         NaN
# 1      Afghanistan 1851-01-01      AFG   3769828.0           NaN         NaN
# 2      Afghanistan 1852-01-01      AFG   3787706.0           NaN         NaN
# 3      Afghanistan 1853-01-01      AFG   3806634.0           NaN         NaN
# 4      Afghanistan 1854-01-01      AFG   3825655.0           NaN         NaN
# ...            ...        ...      ...         ...           ...         ...
# 46518     Zimbabwe 2017-01-01      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe 2018-01-01      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe 2019-01-01      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe 2020-01-01      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe 2021-01-01      ZWE  15993525.0           NaN       0.570
#
# ...

# %%
df_ts = df_ts[ ['country', 'year','co2'] ]

# %%
df_ts
# Out:
#            country       year     co2
# 0      Afghanistan 1850-01-01     NaN
# 1      Afghanistan 1851-01-01     NaN
# 2      Afghanistan 1852-01-01     NaN
# 3      Afghanistan 1853-01-01     NaN
# 4      Afghanistan 1854-01-01     NaN
# ...            ...        ...     ...
# 46518     Zimbabwe 2017-01-01   9.596
# 46519     Zimbabwe 2018-01-01  11.795
# 46520     Zimbabwe 2019-01-01  11.115
# 46521     Zimbabwe 2020-01-01  10.608
# 46522     Zimbabwe 2021-01-01  11.296
#
# [46523 rows x 3 columns]

# %%
df_us_ts = df_ts.loc[ (df_ts['country'] == 'United States') , :]
df_us_ts.isna().sum()
# Out:
# country    0
# year       0
# co2        0
# dtype: int64

# %%
df_us_ts
# Out:
#              country       year       co2
# 44001  United States 1800-01-01     0.253
# 44002  United States 1801-01-01     0.267
# 44003  United States 1802-01-01     0.289
# 44004  United States 1803-01-01     0.297
# 44005  United States 1804-01-01     0.333
# ...              ...        ...       ...
# 44218  United States 2017-01-01  5210.958
# 44219  United States 2018-01-01  5376.657
# 44220  United States 2019-01-01  5259.144
# 44221  United States 2020-01-01  4715.691
# 44222  United States 2021-01-01  5007.336
#
# [222 rows x 3 columns]

# %%
plt.plot(df_us_ts['year'], df_us_ts['co2'],label='co2 emmision_us')

# %%
# df_us_ts['date'] = pd.to_datetime(df['year'].astype(str) + '-01-01')

# %%
df_us_ts.set_index('year', inplace=True)

# %%
df_us_ts
# Out:
#                   country       co2
# year
# 1800-01-01  United States     0.253
# 1801-01-01  United States     0.267
# 1802-01-01  United States     0.289
# 1803-01-01  United States     0.297
# 1804-01-01  United States     0.333
# ...                   ...       ...
# 2017-01-01  United States  5210.958
# 2018-01-01  United States  5376.657
# 2019-01-01  United States  5259.144
# 2020-01-01  United States  4715.691
# 2021-01-01  United States  5007.336
#
# [222 rows x 2 columns]

# %%
df_us_ts.isna().sum()
# Out:
# country    0
# co2        0
# dtype: int64

# %%
df_us_ts = df_us_ts.asfreq("YS")

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# Multiplicative Decomposition 
result_mul = seasonal_decompose(df_us_ts['co2'], model='multiplicative', extrapolate_trend='freq')

# Additive Decomposition
result_add = seasonal_decompose(df_us_ts['co2'], model='additive', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (7,7)})
result_mul.plot().suptitle('Multiplicative Decompose', fontsize=22)
result_add.plot().suptitle('Additive Decompose', fontsize=22)
plt.show()

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pmdarima as pm
from pmdarima.model_selection import train_test_split

# %%
df_us_ts
# Out:
#                   country       co2
# year
# 1800-01-01  United States     0.253
# 1801-01-01  United States     0.267
# 1802-01-01  United States     0.289
# 1803-01-01  United States     0.297
# 1804-01-01  United States     0.333
# ...                   ...       ...
# 2017-01-01  United States  5210.958
# 2018-01-01  United States  5376.657
# 2019-01-01  United States  5259.144
# 2020-01-01  United States  4715.691
# 2021-01-01  United States  5007.336
#
# [222 rows x 2 columns]

# %%
test_size = int(0.05 * df_us_ts.shape[0])
train, test = train_test_split(df_us_ts['co2'],test_size = test_size)

# %%
train.shape, test.shape
# Out:
# ((211,), (11,))

# %%
train
# Out:
# year
# 1800-01-01       0.253
# 1801-01-01       0.267
# 1802-01-01       0.289
# 1803-01-01       0.297
# 1804-01-01       0.333
#                 ...
# 2006-01-01    6057.163
# 2007-01-01    6135.287
# 2008-01-01    5918.869
# 2009-01-01    5482.978
# 2010-01-01    5681.392
# Freq: AS-JAN, Name: co2, Length: 211, dtype: float64

# %%
test
# Out:
# year
# 2011-01-01    5546.629
# 2012-01-01    5345.454
# 2013-01-01    5480.926
# 2014-01-01    5528.871
# 2015-01-01    5376.578
# 2016-01-01    5251.757
# 2017-01-01    5210.958
# 2018-01-01    5376.657
# 2019-01-01    5259.144
# 2020-01-01    4715.691
# 2021-01-01    5007.336
# Freq: AS-JAN, Name: co2, dtype: float64

# %%
model = pm.auto_arima(train, seasonal=False,trace = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2729.847, Time=0.03 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=2682.739, Time=0.05 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2727.854, Time=0.05 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=2610.992, Time=0.18 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=2609.185, Time=0.15 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=2602.796, Time=0.22 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=2600.515, Time=0.25 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=2598.556, Time=0.15 sec
#  ARIMA(4,2,0)(0,0,0)[0]             : AIC=2600.832, Time=0.12 sec
#  ARIMA(5,2,1)(0,0,0)[0]             : AIC=2578.634, Time=0.33 sec
# ...

# %%
model = pm.ARIMA((3,2,1))

# %%
model.fit(train)
# Out:
# ARIMA(order=(3, 2, 1))

# %%
predictions = model.predict(n_periods = test.shape[0])

# %%
test.shape, predictions.shape
# Out:
# ((11,), (11,))

# %%
test
# Out:
# year
# 2011-01-01    5546.629
# 2012-01-01    5345.454
# 2013-01-01    5480.926
# 2014-01-01    5528.871
# 2015-01-01    5376.578
# 2016-01-01    5251.757
# 2017-01-01    5210.958
# 2018-01-01    5376.657
# 2019-01-01    5259.144
# 2020-01-01    4715.691
# 2021-01-01    5007.336
# Freq: AS-JAN, Name: co2, dtype: float64

# %%
predictions
# Out:
# 2011-01-01    5731.492476
# 2012-01-01    5653.250073
# 2013-01-01    5746.806673
# 2014-01-01    5819.096674
# 2015-01-01    5840.096078
# 2016-01-01    5905.659199
# 2017-01-01    5972.219036
# 2018-01-01    6021.283543
# 2019-01-01    6081.342099
# 2020-01-01    6143.928735
# 2021-01-01    6201.209401
# Freq: AS-JAN, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(test, predictions)
# Out:
# 637.8529987833949

# %%
mean_squared_error(test, predictions)
# Out:
# 551140.152678145

# %%
pm.metrics.smape(test, predictions)
# Out:
# 11.431367359988874

# %% [markdown]
# # Time series as regression of lag values

# %%
df_us_lag = df_us_ts

# %%
df_us_lag['lag1'] = df_us_lag['co2'].shift(1)
df_us_lag['lag2'] = df_us_lag['co2'].shift(2)
df_us_lag['lag3'] = df_us_lag['co2'].shift(3)
df_us_lag['lag4'] = df_us_lag['co2'].shift(4)
df_us_lag['lag5'] = df_us_lag['co2'].shift(5)

# %%
df_us_lag.head(10)
# Out:
#                   country    co2   lag1   lag2   lag3   lag4   lag5
# year
# 1800-01-01  United States  0.253    NaN    NaN    NaN    NaN    NaN
# 1801-01-01  United States  0.267  0.253    NaN    NaN    NaN    NaN
# 1802-01-01  United States  0.289  0.267  0.253    NaN    NaN    NaN
# 1803-01-01  United States  0.297  0.289  0.267  0.253    NaN    NaN
# 1804-01-01  United States  0.333  0.297  0.289  0.267  0.253    NaN
# 1805-01-01  United States  0.341  0.333  0.297  0.289  0.267  0.253
# 1806-01-01  United States  0.333  0.341  0.333  0.297  0.289  0.267
# 1807-01-01  United States  0.377  0.333  0.341  0.333  0.297  0.289
# 1808-01-01  United States  0.392  0.377  0.333  0.341  0.333  0.297
# 1809-01-01  United States  0.403  0.392  0.377  0.333  0.341  0.333

# %%
df_us_lag.dropna(inplace=True)

# %%
df_us_lag
# Out:
#                   country       co2      lag1      lag2      lag3      lag4  \
# year
# 1805-01-01  United States     0.341     0.333     0.297     0.289     0.267
# 1806-01-01  United States     0.333     0.341     0.333     0.297     0.289
# 1807-01-01  United States     0.377     0.333     0.341     0.333     0.297
# 1808-01-01  United States     0.392     0.377     0.333     0.341     0.333
# 1809-01-01  United States     0.403     0.392     0.377     0.333     0.341
# ...                   ...       ...       ...       ...       ...       ...
# 2017-01-01  United States  5210.958  5251.757  5376.578  5528.871  5480.926
# 2018-01-01  United States  5376.657  5210.958  5251.757  5376.578  5528.871
# 2019-01-01  United States  5259.144  5376.657  5210.958  5251.757  5376.578
# 2020-01-01  United States  4715.691  5259.144  5376.657  5210.958  5251.757
# 2021-01-01  United States  5007.336  4715.691  5259.144  5376.657  5210.958
#
#                 lag5
# year
# ...

# %%
X = df_us_lag.loc[:,['lag1','lag2','lag3','lag4','lag5']]
y = df_us_lag.loc[:,'co2']

# %%
X.shape,y.shape
# Out:
# ((217, 5), (217,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,
                                                 test_size=0.1,
                                                 random_state=7)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((195, 5), (22, 5), (195,), (22,))

# %%
from sklearn.linear_model import ElasticNet

# %%
en = ElasticNet(random_state=7)

# %%
en.fit(X_train,y_train, )
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.395e+06, tolerance: 8.843e+04
#   model = cd_fast.enet_coordinate_descent(
# ElasticNet(random_state=7)

# %%
y_pred = en.predict(X_test)

# %%
y_pred.shape,y_test.shape
# Out:
# ((22,), (22,))

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 75.44200986874866

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 11983.608870031232

# %% [markdown]
# # RandomForest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=50,max_depth=5, oob_score=True,random_state=7)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50, oob_score=True,
#                       random_state=7)

# %%
Y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print('mean squared error is ',mean_squared_error(y_test,Y_pred_rf))
print('mean absolute error is ',mean_absolute_error(y_test,Y_pred_rf))
# Out:
# mean squared error is  11970.136472013402
# mean absolute error is  77.54792469869524

# %% [markdown]
# # LSTM

# %%
import tensorflow as tf
from tensorflow import keras

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((195, 5), (22, 5), (195,), (22,))

# %%
X_train[:3].values
# Out:
# array([[ 267.59 ,  253.883,  235.394,  210.193,  198.684],
#        [5737.129, 5691.865, 5616.431, 5427.798, 5365.579],
#        [1423.669, 1738.246, 1479.159, 1747.718, 1670.971]])

# %%
import numpy as np
X_train_lstm = np.reshape(X_train.values, (X_train.shape[0],X_train.shape[1], 1))

# %%
X_train_lstm.shape
# Out:
# (195, 5, 1)

# %%
X_train_lstm[:3]
# Out:
# array([[[ 267.59 ],
#         [ 253.883],
#         [ 235.394],
#         [ 210.193],
#         [ 198.684]],
#
#        [[5737.129],
#         [5691.865],
#         [5616.431],
#         [5427.798],
#         [5365.579]],
#
#        [[1423.669],
#         [1738.246],
#         [1479.159],
#         [1747.718],
#         [1670.971]]])

# %%
model = keras.Sequential()

# Adding LSTM layers
model.add(keras.layers.LSTM(units=1,return_sequences = False, 
                            input_shape= (X_train_lstm.shape[1],X_train_lstm.shape[2])))
# Adding the output layer
model.add(keras.layers.Dense(1, activation='linear'))

# Compiling the LSTM
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
history = model.fit(X_train_lstm, y_train, validation_split=0.1,epochs = 100, batch_size = 5)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 4s 34ms/step - loss: 8585663.0000 - val_loss: 8917536.0000
# Epoch 2/100
# 35/35 [==============================] - 0s 6ms/step - loss: 8585536.0000 - val_loss: 8917398.0000
# Epoch 3/100
# 35/35 [==============================] - 0s 6ms/step - loss: 8585405.0000 - val_loss: 8917267.0000
# Epoch 4/100
# 35/35 [==============================] - 0s 7ms/step - loss: 8585279.0000 - val_loss: 8917126.0000
# Epoch 5/100
# 35/35 [==============================] - 0s 6ms/step - loss: 8585149.0000 - val_loss: 8916989.0000
# Epoch 6/100
# 35/35 [==============================] - 0s 10ms/step - loss: 8585019.0000 - val_loss: 8916851.0000
# Epoch 7/100
# 35/35 [==============================] - 1s 16ms/step - loss: 8584891.0000 - val_loss: 8916715.0000
# Epoch 8/100
# 35/35 [==============================] - 0s 10ms/step - loss: 8584762.0000 - val_loss: 8916581.0000
# Epoch 9/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()

# %%
model = keras.Sequential()

# Adding LSTM layers 
model.add(keras.layers.LSTM(units=500,return_sequences = True, 
                            input_shape= (X_train_lstm.shape[1],X_train_lstm.shape[2])))

model.add(keras.layers.LSTM(units=100,return_sequences = False))
# Adding the output layer
model.add( keras.layers.Dense(1, activation='linear'))

# Compiling the LSTM
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
history = model.fit(X_train_lstm, y_train, validation_split=0.3,epochs = 1000, batch_size = 10)
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 6s 95ms/step - loss: 8552115.0000 - val_loss: 8686383.0000
# Epoch 2/1000
# 14/14 [==============================] - 0s 35ms/step - loss: 8524524.0000 - val_loss: 8669304.0000
# Epoch 3/1000
# 14/14 [==============================] - 0s 35ms/step - loss: 8512964.0000 - val_loss: 8661737.0000
# Epoch 4/1000
# 14/14 [==============================] - 1s 37ms/step - loss: 8505906.0000 - val_loss: 8655013.0000
# Epoch 5/1000
# 14/14 [==============================] - 0s 33ms/step - loss: 8499390.0000 - val_loss: 8649145.0000
# Epoch 6/1000
# 14/14 [==============================] - 0s 31ms/step - loss: 8493633.0000 - val_loss: 8643141.0000
# Epoch 7/1000
# 14/14 [==============================] - 0s 32ms/step - loss: 8487769.0000 - val_loss: 8637210.0000
# Epoch 8/1000
# 14/14 [==============================] - 0s 34ms/step - loss: 8481817.0000 - val_loss: 8631547.0000
# Epoch 9/1000
# ...

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()

# %%
# !pip install pystan
# !pip install fbprophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get install -y build-essential python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-dev is already the newest version (3.8.2-0ubuntu2).
# build-essential is already the newest version (12.8ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# !pip install pystan==2.19.1.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install fbprophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from fbprophet import Prophet

# %%
df_cyc = df[ ['country', 'year','co2'] ]
df_cyc
# Out:
#            country  year     co2
# 0      Afghanistan  1850     NaN
# 1      Afghanistan  1851     NaN
# 2      Afghanistan  1852     NaN
# 3      Afghanistan  1853     NaN
# 4      Afghanistan  1854     NaN
# ...            ...   ...     ...
# 46518     Zimbabwe  2017   9.596
# 46519     Zimbabwe  2018  11.795
# 46520     Zimbabwe  2019  11.115
# 46521     Zimbabwe  2020  10.608
# 46522     Zimbabwe  2021  11.296
#
# [46523 rows x 3 columns]

# %%
df_usa = df_cyc.loc[ (df['country'] == 'United States') , :]
df_usa
# Out:
#              country  year       co2
# 44001  United States  1800     0.253
# 44002  United States  1801     0.267
# 44003  United States  1802     0.289
# 44004  United States  1803     0.297
# 44005  United States  1804     0.333
# ...              ...   ...       ...
# 44218  United States  2017  5210.958
# 44219  United States  2018  5376.657
# 44220  United States  2019  5259.144
# 44221  United States  2020  4715.691
# 44222  United States  2021  5007.336
#
# [222 rows x 3 columns]

# %%
df_usa.isna().sum()
# Out:
# country    0
# year       0
# co2        0
# dtype: int64

# %%
df_usa['date'] = pd.to_datetime(df_usa['year'].astype(str) + '-01-01')
# Out:
# <ipython-input-119-5d04d4b0f6a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['date'] = pd.to_datetime(df_usa['year'].astype(str) + '-01-01')

# %%
df_usa.drop(['country','year'], axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_usa
# Out:
#             co2       date
# 44001     0.253 1800-01-01
# 44002     0.267 1801-01-01
# 44003     0.289 1802-01-01
# 44004     0.297 1803-01-01
# 44005     0.333 1804-01-01
# ...         ...        ...
# 44218  5210.958 2017-01-01
# 44219  5376.657 2018-01-01
# 44220  5259.144 2019-01-01
# 44221  4715.691 2020-01-01
# 44222  5007.336 2021-01-01
#
# [222 rows x 2 columns]

# %%
df_usa = df_usa.rename(columns={'co2': 'y','date':'ds'})
df_usa
# Out:
#               y         ds
# 44001     0.253 1800-01-01
# 44002     0.267 1801-01-01
# 44003     0.289 1802-01-01
# 44004     0.297 1803-01-01
# 44005     0.333 1804-01-01
# ...         ...        ...
# 44218  5210.958 2017-01-01
# 44219  5376.657 2018-01-01
# 44220  5259.144 2019-01-01
# 44221  4715.691 2020-01-01
# 44222  5007.336 2021-01-01
#
# [222 rows x 2 columns]

# %%
m = Prophet(interval_width=0.95)
model = m.fit(df_usa)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=10,freq='Y')
forecast = m.predict(future)
forecast
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   1800-01-01    23.476412  -697.224011   468.672250    23.476412
# 1   1801-01-01    26.321141  -762.733148   476.504186    26.321141
# 2   1802-01-01    29.165871  -700.578509   515.770126    29.165871
# 3   1803-01-01    32.010600  -657.591625   501.235206    32.010600
# 4   1804-01-01    34.855329  -628.797888   551.823067    34.855329
# ..         ...          ...          ...          ...          ...
# 227 2026-12-31  6442.825497  5921.112058  7130.353885  6416.701527
# 228 2027-12-31  6484.628828  5999.103683  7173.051693  6453.226909
# 229 2028-12-31  6526.546688  5942.318163  7127.321058  6487.397504
# 230 2029-12-31  6568.350019  6002.953341  7206.876525  6522.887784
# 231 2030-12-31  6610.153350  6084.013552  7242.849876  6554.793144
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      23.476412     -149.090622           -149.090622           -149.090622
# ...

# %%
plot1 = m.plot(forecast)

# %%
plt2 = m.plot_components(forecast)
