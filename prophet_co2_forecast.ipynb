# %%
import pandas as pd

# %%
df = pd.read_csv('/content/owid-co2-data.csv',parse_dates=['year'])

# %%
df
# Out:
#            country       year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan 1850-01-01      AFG   3752993.0           NaN         NaN
# 1      Afghanistan 1851-01-01      AFG   3769828.0           NaN         NaN
# 2      Afghanistan 1852-01-01      AFG   3787706.0           NaN         NaN
# 3      Afghanistan 1853-01-01      AFG   3806634.0           NaN         NaN
# 4      Afghanistan 1854-01-01      AFG   3825655.0           NaN         NaN
# ...            ...        ...      ...         ...           ...         ...
# 46518     Zimbabwe 2017-01-01      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe 2018-01-01      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe 2019-01-01      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe 2020-01-01      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe 2021-01-01      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 46518                  0.032   9.596          -0.937           -8.899  ...
# 46519                  0.037  11.795           2.199           22.920  ...
# 46520                  0.037  11.115          -0.681           -5.772  ...
# 46521                  0.036  10.608          -0.507           -4.559  ...
# 46522                  0.036  11.296           0.688            6.488  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
# ...                                  ...                       ...
# 46518                                NaN                       0.0
# 46519                                NaN                       0.0
# 46520                                NaN                       0.0
# 46521                                NaN                       0.0
# 46522                                NaN                       0.0
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 0                       NaN                 0.121                   NaN
# 1                       NaN                 0.118                   NaN
# 2                       NaN                 0.116                   NaN
# 3                       NaN                 0.115                   NaN
# 4                       NaN                 0.114                   NaN
# ...                     ...                   ...                   ...
# 46518                   0.0                 0.219                 0.026
# 46519                   0.0                 0.211                 0.033
# 46520                   0.0                 0.183                 0.030
# 46521                   0.0                 0.194                 0.030
# 46522                   0.0                 0.190                 0.030
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 0                         NaN        NaN                       NaN        NaN
# 1                         NaN        NaN                       NaN        NaN
# 2                         NaN        NaN                       NaN        NaN
# 3                         NaN        NaN                       NaN        NaN
# 4                         NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 46518                     NaN     115.59                     28.30      0.910
# 46519                     NaN     118.22                     30.83      0.771
# 46520                     NaN     117.96                     30.53      0.978
# 46521                     NaN        NaN                       NaN      1.006
# 46522                     NaN        NaN                       NaN        NaN
#
#        trade_co2_share
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 46518            9.486
# 46519            6.537
# 46520            8.795
# 46521            9.481
# 46522              NaN
#
# [46523 rows x 74 columns]

# %%
df_a = df[ ['country', 'year','co2'] ]
df_a
# Out:
#            country       year     co2
# 0      Afghanistan 1850-01-01     NaN
# 1      Afghanistan 1851-01-01     NaN
# 2      Afghanistan 1852-01-01     NaN
# 3      Afghanistan 1853-01-01     NaN
# 4      Afghanistan 1854-01-01     NaN
# ...            ...        ...     ...
# 46518     Zimbabwe 2017-01-01   9.596
# 46519     Zimbabwe 2018-01-01  11.795
# 46520     Zimbabwe 2019-01-01  11.115
# 46521     Zimbabwe 2020-01-01  10.608
# 46522     Zimbabwe 2021-01-01  11.296
#
# [46523 rows x 3 columns]

# %%
df_ind = df_a.loc[ (df['country'] == 'India') , :]
df_ind
# Out:
#       country       year       co2
# 19966   India 1850-01-01       NaN
# 19967   India 1851-01-01       NaN
# 19968   India 1852-01-01       NaN
# 19969   India 1853-01-01       NaN
# 19970   India 1854-01-01       NaN
# ...       ...        ...       ...
# 20133   India 2017-01-01  2434.868
# 20134   India 2018-01-01  2600.447
# 20135   India 2019-01-01  2626.459
# 20136   India 2020-01-01  2445.012
# 20137   India 2021-01-01  2709.684
#
# [172 rows x 3 columns]

# %%
df_ind_clean = df_ind.dropna()

# %%
df_ind_clean.isna().sum()
# Out:
# country    0
# year       0
# co2        0
# dtype: int64

# %%
df_ind_clean.drop('country',axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_ind_clean
# Out:
#             year       co2
# 19974 1858-01-01     0.394
# 19975 1859-01-01     0.636
# 19976 1860-01-01     0.643
# 19977 1861-01-01     0.497
# 19978 1862-01-01     0.550
# ...          ...       ...
# 20133 2017-01-01  2434.868
# 20134 2018-01-01  2600.447
# 20135 2019-01-01  2626.459
# 20136 2020-01-01  2445.012
# 20137 2021-01-01  2709.684
#
# [153 rows x 2 columns]

# %%
df_ind_clean = df_ind_clean.rename(columns={'co2': 'y','year':'ds'})
df_ind_clean
# Out:
#               ds         y
# 19974 1858-01-01     0.394
# 19975 1859-01-01     0.636
# 19976 1860-01-01     0.643
# 19977 1861-01-01     0.497
# 19978 1862-01-01     0.550
# ...          ...       ...
# 20133 2017-01-01  2434.868
# 20134 2018-01-01  2600.447
# 20135 2019-01-01  2626.459
# 20136 2020-01-01  2445.012
# 20137 2021-01-01  2709.684
#
# [153 rows x 2 columns]

# %%
# !pip install pystan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pystan in /usr/local/lib/python3.8/dist-packages (3.3.0)
# Requirement already satisfied: clikit<0.7,>=0.6 in /usr/local/lib/python3.8/dist-packages (from pystan) (0.6.2)
# Requirement already satisfied: pysimdjson<4.0,>=3.2 in /usr/local/lib/python3.8/dist-packages (from pystan) (3.2.0)
# Requirement already satisfied: httpstan<4.7,>=4.6 in /usr/local/lib/python3.8/dist-packages (from pystan) (4.6.1)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /usr/local/lib/python3.8/dist-packages (from pystan) (3.8.4)
# Requirement already satisfied: numpy<2.0,>=1.7 in /usr/local/lib/python3.8/dist-packages (from pystan) (1.22.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0,>=3.6->pystan) (22.2.0)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from clikit<0.7,>=0.6->pystan) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /usr/local/lib/python3.8/dist-packages (from clikit<0.7,>=0.6->pystan) (1.4.0)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from clikit<0.7,>=0.6->pystan) (0.3.1)
# Requirement already satisfied: setuptools>=41.0 in /usr/local/lib/python3.8/dist-packages (from httpstan<4.7,>=4.6->pystan) (57.4.0)
# Requirement already satisfied: webargs<9.0,>=8.0 in /usr/local/lib/python3.8/dist-packages (from httpstan<4.7,>=4.6->pystan) (8.2.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /usr/local/lib/python3.8/dist-packages (from httpstan<4.7,>=4.6->pystan) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /usr/local/lib/python3.8/dist-packages (from httpstan<4.7,>=4.6->pystan) (3.19.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.8/dist-packages (from marshmallow<4.0,>=3.10->httpstan<4.7,>=4.6->pystan) (23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan) (2.10)

# %%
# !apt-get install -y build-essential python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-dev is already the newest version (3.8.2-0ubuntu2).
# python3-dev set to manually installed.
# build-essential is already the newest version (12.8ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# !pip install pystan==2.19.1.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pystan==2.19.1.1
#   Downloading pystan-2.19.1.1-cp38-cp38-manylinux1_x86_64.whl (62.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.8/dist-packages (from pystan==2.19.1.1) (1.22.4)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /usr/local/lib/python3.8/dist-packages (from pystan==2.19.1.1) (0.29.33)
# Installing collected packages: pystan
#   Attempting uninstall: pystan
#     Found existing installation: pystan 3.3.0
#     Uninstalling pystan-3.3.0:
#       Successfully uninstalled pystan-3.3.0
# Successfully installed pystan-2.19.1.1

# %%
# !pip install fbprophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fbprophet
#   Downloading fbprophet-0.7.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 KB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (0.29.33)
# Collecting cmdstanpy==0.9.5
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Requirement already satisfied: pystan>=2.14 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (2.19.1.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (1.22.4)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (1.3.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (3.5.3)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (2.4.0)
# Requirement already satisfied: holidays>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (0.20)
# Collecting setuptools-git>=1.2
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.8/dist-packages (from fbprophet) (4.64.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.8/dist-packages (from convertdate>=2.1.2->fbprophet) (0.5.12)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.8/dist-packages (from holidays>=0.10.2->fbprophet) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.8/dist-packages (from holidays>=0.10.2->fbprophet) (0.3.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from LunarCalendar>=0.0.9->fbprophet) (2022.7.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.8/dist-packages (from LunarCalendar>=0.0.9->fbprophet) (4.1.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0.0->fbprophet) (23.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0.0->fbprophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0.0->fbprophet) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0.0->fbprophet) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0.0->fbprophet) (8.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.0->fbprophet) (1.15.0)
# Building wheels for collected packages: fbprophet
#   Building wheel for fbprophet (setup.py) ... done
#   Created wheel for fbprophet: filename=fbprophet-0.7.1-py3-none-any.whl size=9537371 sha256=7ead34916121a675ff245918bc5fe5db3cac937d02c071728bb9639669e519e6
#   Stored in directory: /root/.cache/pip/wheels/d0/d2/ae/c579b7fd160999d35908f3cb8ebcad7ef64ecaca7b78e4c3c8
# Successfully built fbprophet
# Installing collected packages: setuptools-git, cmdstanpy, fbprophet
#   Attempting uninstall: cmdstanpy
#     Found existing installation: cmdstanpy 1.1.0
#     Uninstalling cmdstanpy-1.1.0:
#       Successfully uninstalled cmdstanpy-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# prophet 1.1.2 requires cmdstanpy>=1.0.4, but you have cmdstanpy 0.9.5 which is incompatible.
# Successfully installed cmdstanpy-0.9.5 fbprophet-0.7.1 setuptools-git-1.2

# %%
from fbprophet import Prophet

# %%
from prophet.plot import plot_plotly, plot_components_plotly

# %%
df_ind_clean.plot(x='ds',y='y',figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
len(df_ind_clean)
# Out:
# 153

# %%
train_ind = df_ind_clean.iloc[:len(df_ind_clean)-20]
test_ind = df_ind_clean.iloc[len(df_ind_clean)-20:]

# %%
train_ind
# Out:
#               ds        y
# 19974 1858-01-01    0.394
# 19975 1859-01-01    0.636
# 19976 1860-01-01    0.643
# 19977 1861-01-01    0.497
# 19978 1862-01-01    0.550
# ...          ...      ...
# 20113 1997-01-01  858.935
# 20114 1998-01-01  876.952
# 20115 1999-01-01  950.951
# 20116 2000-01-01  978.104
# 20117 2001-01-01  991.732
#
# [133 rows x 2 columns]

# %%
test_ind
# Out:
#               ds         y
# 20118 2002-01-01  1022.175
# 20119 2003-01-01  1058.725
# 20120 2004-01-01  1124.518
# 20121 2005-01-01  1184.927
# 20122 2006-01-01  1258.643
# 20123 2007-01-01  1356.953
# 20124 2008-01-01  1461.518
# 20125 2009-01-01  1611.416
# 20126 2010-01-01  1676.495
# 20127 2011-01-01  1778.473
# 20128 2012-01-01  1962.594
# 20129 2013-01-01  2037.416
# 20130 2014-01-01  2187.343
# 20131 2015-01-01  2270.766
# 20132 2016-01-01  2383.816
# 20133 2017-01-01  2434.868
# 20134 2018-01-01  2600.447
# 20135 2019-01-01  2626.459
# 20136 2020-01-01  2445.012
# 20137 2021-01-01  2709.684

# %%
m_ind = Prophet()
m_ind.fit(train_ind)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_ind = m_ind.make_future_dataframe(periods=21,freq='Y')
forecast_ind = m_ind.predict(future_ind)
forecast_ind
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   1858-01-01     3.469077   -48.703505    23.780828     3.469077
# 1   1859-01-01     4.116346   -46.284705    23.911967     4.116346
# 2   1860-01-01     4.763615   -45.948517    25.758431     4.763615
# 3   1861-01-01     5.412658   -48.897136    24.230629     5.412658
# 4   1862-01-01     6.059927   -47.101187    29.492770     6.059927
# ..         ...          ...          ...          ...          ...
# 149 2017-12-31  1373.024698  1313.703623  1406.461581  1345.223959
# 150 2018-12-31  1399.748174  1341.288682  1436.009568  1369.326214
# 151 2019-12-31  1426.471650  1368.522304  1467.397807  1392.831999
# 152 2020-12-31  1453.268341  1390.866983  1493.490608  1416.346041
# 153 2021-12-31  1479.991817  1413.468183  1524.367702  1440.404750
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0       3.469077      -14.873129            -14.873129            -14.873129
# 1       4.116346      -14.550992            -14.550992            -14.550992
# 2       4.763615      -14.195788            -14.195788            -14.195788
# 3       5.412658      -15.161872            -15.161872            -15.161872
# 4       6.059927      -14.873129            -14.873129            -14.873129
# ..           ...             ...                   ...                   ...
# 149  1402.363943      -11.394980            -11.394980            -11.394980
# 150  1432.768479      -10.821788            -10.821788            -10.821788
# 151  1461.707660      -10.219981            -10.219981            -10.219981
# 152  1491.150484      -11.938829            -11.938829            -11.938829
# 153  1520.402411      -11.394980            -11.394980            -11.394980
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -14.873129    -14.873129    -14.873129                   0.0
# 1   -14.550992    -14.550992    -14.550992                   0.0
# 2   -14.195788    -14.195788    -14.195788                   0.0
# 3   -15.161872    -15.161872    -15.161872                   0.0
# 4   -14.873129    -14.873129    -14.873129                   0.0
# ..         ...           ...           ...                   ...
# 149 -11.394980    -11.394980    -11.394980                   0.0
# 150 -10.821788    -10.821788    -10.821788                   0.0
# 151 -10.219981    -10.219981    -10.219981                   0.0
# 152 -11.938829    -11.938829    -11.938829                   0.0
# 153 -11.394980    -11.394980    -11.394980                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                           0.0                         0.0   -11.404052
# 1                           0.0                         0.0   -10.434646
# 2                           0.0                         0.0    -9.432173
# 3                           0.0                         0.0    -9.749214
# 4                           0.0                         0.0    -8.813202
# ..                          ...                         ...          ...
# 149                         0.0                         0.0  1361.629718
# 150                         0.0                         0.0  1388.926386
# 151                         0.0                         0.0  1416.251669
# 152                         0.0                         0.0  1441.329512
# 153                         0.0                         0.0  1468.596837
#
# [154 rows x 16 columns]

# %%
plot1 = m_ind.plot(forecast_ind)

# %%
predictions_ind = forecast_ind.iloc[-20:]['yhat']

# %%
predictions_ind.shape,test_ind['y'].shape
# Out:
# ((20,), (20,))

# %%
test_ind['y']
# Out:
# 20118    1022.175
# 20119    1058.725
# 20120    1124.518
# 20121    1184.927
# 20122    1258.643
# 20123    1356.953
# 20124    1461.518
# 20125    1611.416
# 20126    1676.495
# 20127    1778.473
# 20128    1962.594
# 20129    2037.416
# 20130    2187.343
# 20131    2270.766
# 20132    2383.816
# 20133    2434.868
# 20134    2600.447
# 20135    2626.459
# 20136    2445.012
# 20137    2709.684
# Name: y, dtype: float64

# %%
from statsmodels.tools.eval_measures import rmse,mse

# %%
rmse(test_ind['y'],predictions_ind)
# Out:
# 764.5933616157591

# %%
mse(test_ind['y'],predictions_ind)
# Out:
# 584603.008626887

# %% [markdown]
# # UK

# %%
df_uk = df_a.loc[ (df_a['country'] == 'United Kingdom') , :]
df_uk.isna().sum()
# Out:
# country    0
# year       0
# co2        0
# dtype: int64

# %%
df_uk
# Out:
#               country       year      co2
# 43729  United Kingdom 1750-01-01    9.351
# 43730  United Kingdom 1751-01-01    9.351
# 43731  United Kingdom 1752-01-01    9.354
# 43732  United Kingdom 1753-01-01    9.354
# 43733  United Kingdom 1754-01-01    9.358
# ...               ...        ...      ...
# 43996  United Kingdom 2017-01-01  387.367
# 43997  United Kingdom 2018-01-01  379.730
# 43998  United Kingdom 2019-01-01  364.753
# 43999  United Kingdom 2020-01-01  326.263
# 44000  United Kingdom 2021-01-01  346.773
#
# [272 rows x 3 columns]

# %%
df_uk_last = df_uk.loc[ (df_uk['year'] > '1950-01-01'), :]

# %%
df_uk_last
# Out:
#               country       year      co2
# 43930  United Kingdom 1951-01-01  545.253
# 43931  United Kingdom 1952-01-01  528.706
# 43932  United Kingdom 1953-01-01  540.211
# 43933  United Kingdom 1954-01-01  553.010
# 43934  United Kingdom 1955-01-01  576.952
# ...               ...        ...      ...
# 43996  United Kingdom 2017-01-01  387.367
# 43997  United Kingdom 2018-01-01  379.730
# 43998  United Kingdom 2019-01-01  364.753
# 43999  United Kingdom 2020-01-01  326.263
# 44000  United Kingdom 2021-01-01  346.773
#
# [71 rows x 3 columns]

# %%
df_uk_fb = df_uk_last.drop('country',axis=1)
df_uk_fb
# Out:
#             year      co2
# 43930 1951-01-01  545.253
# 43931 1952-01-01  528.706
# 43932 1953-01-01  540.211
# 43933 1954-01-01  553.010
# 43934 1955-01-01  576.952
# ...          ...      ...
# 43996 2017-01-01  387.367
# 43997 2018-01-01  379.730
# 43998 2019-01-01  364.753
# 43999 2020-01-01  326.263
# 44000 2021-01-01  346.773
#
# [71 rows x 2 columns]

# %%
df_fb = df_uk_fb.rename(columns={'co2': 'y','year':'ds'})
df_fb
# Out:
#               ds        y
# 43930 1951-01-01  545.253
# 43931 1952-01-01  528.706
# 43932 1953-01-01  540.211
# 43933 1954-01-01  553.010
# 43934 1955-01-01  576.952
# ...          ...      ...
# 43996 2017-01-01  387.367
# 43997 2018-01-01  379.730
# 43998 2019-01-01  364.753
# 43999 2020-01-01  326.263
# 44000 2021-01-01  346.773
#
# [71 rows x 2 columns]

# %%
df_fb.plot(x='ds',y='y',figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
len(df_fb)
# Out:
# 71

# %%
0.1*len(df_fb)
# Out:
# 7.1000000000000005

# %%
train_uk = df_fb.iloc[:len(df_fb)-int((0.1*len(df_fb)))]
test_uk = df_fb.iloc[len(df_fb)-int((0.1*len(df_fb))):]

# %%
train_uk
# Out:
#               ds        y
# 43930 1951-01-01  545.253
# 43931 1952-01-01  528.706
# 43932 1953-01-01  540.211
# 43933 1954-01-01  553.010
# 43934 1955-01-01  576.952
# ...          ...      ...
# 43989 2010-01-01  511.905
# 43990 2011-01-01  469.713
# 43991 2012-01-01  487.477
# 43992 2013-01-01  477.611
# 43993 2014-01-01  438.807
#
# [64 rows x 2 columns]

# %%
test_uk
# Out:
#               ds        y
# 43994 2015-01-01  422.461
# 43995 2016-01-01  399.430
# 43996 2017-01-01  387.367
# 43997 2018-01-01  379.730
# 43998 2019-01-01  364.753
# 43999 2020-01-01  326.263
# 44000 2021-01-01  346.773

# %%
m_uk = Prophet()
m_uk.fit(train_uk)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_uk = m_uk.make_future_dataframe(periods=6,freq='Y')
forecast_uk = m_uk.predict(future_uk)
forecast_uk
# Out:
#            ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1951-01-01  22.924424  520.547546  589.600725    22.924424    22.924424
# 1  1952-01-01  26.125257  524.935726  590.523584    26.125257    26.125257
# 2  1953-01-01  29.334860  525.982025  589.783422    29.334860    29.334860
# 3  1954-01-01  32.535693  530.096417  596.506069    32.535693    32.535693
# 4  1955-01-01  35.736526  532.240329  599.135837    35.736526    35.736526
# ..        ...        ...         ...         ...          ...          ...
# 65 2015-12-31 -34.198780  462.801614  529.147317   -34.579999   -33.805356
# 66 2016-12-31 -37.798876  461.195968  526.743275   -38.594246   -37.023344
# 67 2017-12-31 -41.389136  456.623311  522.040756   -42.654349   -40.122596
# 68 2018-12-31 -44.979395  452.747976  516.164294   -46.702218   -43.088571
# 69 2019-12-31 -48.569655  447.254547  512.817871   -50.989749   -45.962101
#
#     additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0       531.323154            531.323154            531.323154  531.323154
# 1       531.307160            531.307160            531.307160  531.307160
# 2       530.803891            530.803891            530.803891  530.803891
# 3       531.154965            531.154965            531.154965  531.154965
# 4       531.323154            531.323154            531.323154  531.323154
# ..             ...                   ...                   ...         ...
# 65      529.379578            529.379578            529.379578  529.379578
# 66      531.105803            531.105803            531.105803  531.105803
# 67      530.718024            530.718024            530.718024  530.718024
# 68      530.142886            530.142886            530.142886  530.142886
# 69      529.379578            529.379578            529.379578  529.379578
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0     531.323154    531.323154                   0.0
# 1     531.307160    531.307160                   0.0
# 2     530.803891    530.803891                   0.0
# 3     531.154965    531.154965                   0.0
# 4     531.323154    531.323154                   0.0
# ..           ...           ...                   ...
# 65    529.379578    529.379578                   0.0
# 66    531.105803    531.105803                   0.0
# 67    530.718024    530.718024                   0.0
# 68    530.142886    530.142886                   0.0
# 69    529.379578    529.379578                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                          0.0                         0.0  554.247579
# 1                          0.0                         0.0  557.432418
# 2                          0.0                         0.0  560.138751
# 3                          0.0                         0.0  563.690658
# 4                          0.0                         0.0  567.059680
# ..                         ...                         ...         ...
# 65                         0.0                         0.0  495.180798
# 66                         0.0                         0.0  493.306927
# 67                         0.0                         0.0  489.328888
# 68                         0.0                         0.0  485.163490
# 69                         0.0                         0.0  480.809923
#
# [70 rows x 16 columns]

# %%
plot_uk = m_uk.plot(forecast_uk)

# %%
plt_uk = m_uk.plot_components(forecast_uk)

# %%
predictions_uk = forecast_uk.iloc[-int((0.1*len(df_fb))):]['yhat']

# %%
predictions_uk.shape,test_uk['y'].shape
# Out:
# ((7,), (7,))

# %%
rmse(test_uk['y'],predictions_uk)
# Out:
# 119.49186803681603

# %%
mse(test_uk['y'],predictions_uk)
# Out:
# 14278.306526927856

# %% [markdown]
# # making future forecast for UK

# %%
m_uk_fut = Prophet()
m_uk_fut.fit(df_fb)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_uk_fut = m_uk_fut.make_future_dataframe(periods=10,freq='Y')
forecast_uk_fut = m_uk_fut.predict(future_uk_fut)
forecast_uk_fut
# Out:
#            ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1951-01-01  -23.351776  525.991773  578.618720   -23.351776   -23.351776
# 1  1952-01-01  -20.078176  524.796812  580.288612   -20.078176   -20.078176
# 2  1953-01-01  -16.795607  533.823616  587.167321   -16.795607   -16.795607
# 3  1954-01-01  -13.522008  536.557306  591.074318   -13.522008   -13.522008
# 4  1955-01-01  -10.248408  538.168911  594.351068   -10.248408   -10.248408
# ..        ...         ...         ...         ...          ...          ...
# 76 2026-12-31 -306.919089  225.327219  282.016156  -312.589949  -301.751275
# 77 2027-12-31 -320.327085  205.930795  262.056768  -327.550185  -313.653072
# 78 2028-12-31 -333.771816  208.332501  265.257654  -342.583631  -325.347512
# 79 2029-12-31 -347.179812  187.996427  248.360844  -357.380809  -337.326956
# 80 2030-12-31 -360.587808  166.855278  230.515617  -372.941270  -348.786652
#
#     additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0       575.837576            575.837576            575.837576  575.837576
# 1       573.672168            573.672168            573.672168  573.672168
# 2       576.650577            576.650577            576.650577  576.650577
# 3       576.830606            576.830606            576.830606  576.830606
# 4       575.837576            575.837576            575.837576  575.837576
# ..             ...                   ...                   ...         ...
# 76      560.176127            560.176127            560.176127  560.176127
# 77      553.364831            553.364831            553.364831  553.364831
# 78      570.336908            570.336908            570.336908  570.336908
# 79      565.836160            565.836160            565.836160  565.836160
# 80      560.176127            560.176127            560.176127  560.176127
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0     575.837576    575.837576                   0.0
# 1     573.672168    573.672168                   0.0
# 2     576.650577    576.650577                   0.0
# 3     576.830606    576.830606                   0.0
# 4     575.837576    575.837576                   0.0
# ..           ...           ...                   ...
# 76    560.176127    560.176127                   0.0
# 77    553.364831    553.364831                   0.0
# 78    570.336908    570.336908                   0.0
# 79    565.836160    565.836160                   0.0
# 80    560.176127    560.176127                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                          0.0                         0.0  552.485800
# 1                          0.0                         0.0  553.593992
# 2                          0.0                         0.0  559.854970
# 3                          0.0                         0.0  563.308598
# 4                          0.0                         0.0  565.589168
# ..                         ...                         ...         ...
# 76                         0.0                         0.0  253.257038
# 77                         0.0                         0.0  233.037746
# 78                         0.0                         0.0  236.565092
# 79                         0.0                         0.0  218.656349
# 80                         0.0                         0.0  199.588318
#
# [81 rows x 16 columns]

# %%
plot_uk_fut = m_uk_fut.plot(forecast_uk_fut)

# %%
def prophet(country,year):
    df_con = df_a.loc[ (df_a['country'] == country) , :]
    df_con.dropna(inplace=True)
    df_con_last = df_con.loc[ (df_con['year'] > year), :]
    df_con_fb = df_con_last.drop('country',axis=1)
    df_fbp = df_con_fb.rename(columns={'co2': 'y','year':'ds'})
    df_fbp.plot(x='ds',y='y',figsize=(12,8))
    train = df_fbp.iloc[:len(df_fbp)-int((0.1*len(df_fbp)))]
    test = df_fbp.iloc[len(df_fbp)-int((0.1*len(df_fbp))):]
    m = Prophet()
    m.fit(train)
    future = m.make_future_dataframe(periods=int((0.1*len(df_fbp))),freq='Y')
    forecast = m.predict(future)
    plotpred = m.plot(forecast)
    predictions = forecast.iloc[-int((0.1*len(df_fbp))):]['yhat']
    print('mean squared error is',mse(test['y'],predictions))
    print('root mean squared error is ',rmse(test['y'],predictions))

# %%
prophet('Iran','1950-01-01')
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# mean squared error is 129.57030859701965
# root mean squared error is  11.382895439958132

# %%
def prophet_forecast(country,year,num_periods):
    df_con = df_a.loc[ (df_a['country'] == country) , :]
    df_con.dropna(inplace=True)
    df_con_last = df_con.loc[ (df_con['year'] > year), :]
    df_con_fb = df_con_last.drop('country',axis=1)
    df_fbp = df_con_fb.rename(columns={'co2': 'y','year':'ds'})
    df_fbp.plot(x='ds',y='y',figsize=(12,8))
    # train = df_fbp.iloc[:len(df_fbp)-int((0.1*len(df_fbp)))]
    # test = df_fbp.iloc[len(df_fbp)-int((0.1*len(df_fbp))):]
    m = Prophet()
    m.fit(df_fbp)
    future = m.make_future_dataframe(periods=num_periods,freq='Y')
    forecast = m.predict(future)
    plotpred = m.plot(forecast)
    # predictions = forecast.iloc[-int((0.1*len(df_fb))):]['yhat']
    # print('root mean squared error is ',rmse(test['y'],predictions))

# %%
prophet_forecast('Iran','1950-01-01',10)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
